# %% [markdown]
# ## Load packages

# %%
import numpy as np
import pandas as pd
import math
from keras import optimizers
from keras import layers
from keras.layers import *
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras import callbacks
from numpy import save
import seaborn as sns
cm = plt.get_cmap('gist_ncar')

import keras.backend as K
import tensorflow as tf
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from matplotlib import pyplot
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import multilabel_confusion_matrix, classification_report

import geopandas as gpd
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# set number of cores to 8
# K.set_session(tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=8, 
#                                                    inter_op_parallelism_threads=8)))

# %% [markdown]
# ## Load dataset

# %%
# import Matt's 'chr1_ukb_X.npz' file
chr1_ukb_X = np.load('/home/magu/deepmix/data/ALL_DNA_dataset/chr1_1kg_X.npz')
# create dict mapping from sampleid to population name
sampleid_to_population_pandas_df = pd.read_csv('/home/jsokol/Data/igsr_samples_cleaned_version.tsv', delimiter="\t")
sampleid_to_population_dict = sampleid_to_population_pandas_df.set_index('Sample name')['Population code'].to_dict()
# remove samples from chr1_ukb_X that are not in dict or that do not contain value
temp = set()
for x in np.nditer(chr1_ukb_X['S']):
    sample_id = str((x.item(0))).replace("'", "").replace("b", "").split("_")[0]
    if sample_id not in sampleid_to_population_dict:
        print(sample_id + ' is not in dict. Make sure to remove this sample from the dataset.')
    elif sampleid_to_population_dict[sample_id] == float('nan'):
        print(sample_id + ' maps to nan in dict')
chr1_ukb_X_G = chr1_ukb_X['G'][:,:,:]
chr1_ukb_X_V = chr1_ukb_X['V'][:,:]
# flatten input data
X_all_data = chr1_ukb_X_G.reshape(chr1_ukb_X_G.shape[0], -1).T

# %%
# create dict mapping from sample to population
populations_represented_set = set()
for i in range(5008):
    sample_id = str(chr1_ukb_X['S'][i].item(0)).replace("'", "").replace("b", "").split("_")[0]
    populations_represented_set.add(sampleid_to_population_dict[sample_id])
# print total number of populations represented by dataset
n_classes = len(populations_represented_set)
print('Total number of classes minus classes deleted because they are admixed = ' + str(n_classes))
print(populations_represented_set)
# Out:
# Total number of classes minus classes deleted because they are admixed = 26
# {'BEB', 'STU', 'CDX', 'PEL', 'CEU', 'IBS', 'JPT', 'GIH', 'CHS', 'ITU', 'MSL', 'ASW', 'TSI', 'GBR', 'CLM', 'KHV', 'PUR', 'ACB', 'GWD', 'CHB', 'LWK', 'MXL', 'PJL', 'FIN', 'YRI', 'ESN'}

# %%
# create dict mapping from population to coordinate tuple
pop_info_df=pd.read_csv('/home/jsokol/Data/igsr_population_coordinates.tsv', sep='\t')
pop_info_df['coordinate_tuples'] = tuple(zip(pop_info_df['Population latitude'], pop_info_df['Population longitude']))
pop_to_coordinate_dict = pop_info_df.set_index('Population code')['coordinate_tuples'].to_dict()

# %%
# create 'Y_all_data' matrix containing labels
Y_all_data = np.zeros((2, 5008))
indices_to_delete = list()
for i in range(5008):
    sample_id = str(chr1_ukb_X['S'][i].item(0)).replace("'", "").replace("b", "").split("_")[0]
    Y_all_data[0,i] = pop_to_coordinate_dict[sampleid_to_population_dict[sample_id]][0]
    Y_all_data[1,i] = pop_to_coordinate_dict[sampleid_to_population_dict[sample_id]][1]
# delete samples with unwanted classes using 'indices_to_delete'
X_all_data = np.delete(X_all_data, indices_to_delete, 1)
Y_all_data = np.delete(Y_all_data, indices_to_delete, 1)
# rescale the longitudes and latitudes
Y_all_data[1,:] = (Y_all_data[1,:]/180)
Y_all_data[0,:] = (Y_all_data[0,:]/90)

# %%
# randomly shuffle the order of the data
randomize = np.arange(X_all_data.shape[1])
np.random.shuffle(randomize)
X_all_data = X_all_data[:,randomize]
Y_all_data = Y_all_data[:,randomize]

# %%
# split data into training and test sets
X_train = X_all_data[:,:int(X_all_data.shape[1]*0.8)]
X_test = X_all_data[:,int(X_all_data.shape[1]*0.8):]
Y_train = Y_all_data[:,:int(X_all_data.shape[1]*0.8)]
Y_test = Y_all_data[:,int(X_all_data.shape[1]*0.8):]
# convert to correct format for use in keras
X_train = X_train[:,:,np.newaxis]
X_train = np.transpose(X_train, (1, 0, 2))
X_test = X_test[:,:,np.newaxis]
X_test = np.transpose(X_test, (1, 0, 2))
Y_train = np.transpose(Y_train, (1, 0))
Y_test = np.transpose(Y_test, (1, 0))

# %% [markdown]
# ## Build model

# %%
def model2(n_snps_per_sample):
    """
    input_shape: The height, width and channels as a tuple.  
        Note that this does not include the 'batch' as a dimension.
        If you have a batch like 'X_train', 
        then you can provide the input_shape using
        X_train.shape[1:]
    """
    
    # Define the input placeholder as a tensor with shape input_shape. Think of this as your input image!
    X_input = Input(shape=(n_snps_per_sample, 1))

    # First convolutional block
    X = Conv1D(filters=49, kernel_size=500 ,strides=500, padding = 'valid', name = 'conv0')(X_input)
    X = BatchNormalization(axis = -1, name = 'bn0')(X)
    X = Activation('relu')(X)

    # Second convolutional block
    X = Conv1D(49, 75, strides = 5, padding = 'same', name = 'conv1')(X)
    X = BatchNormalization(axis = -1, name = 'bn1')(X)
    X = Activation('relu')(X)
    
    # MAXPOOL
    X = MaxPooling1D(2, name='max_pool')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(1127, activation='relu')(X)
    X = Dense(20, activation='relu')(X)
    X = Dense(2, activation='tanh', name='fc')(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='model2')
    
    return model

# %% [markdown]
# ## Create and compile the model

# %%
# create model
model2 = model2(X_train.shape[1])
# compile model
adam_optimizer_fn = optimizers.Adam(lr=0.0001, beta_1=0.99, beta_2=0.999, amsgrad=False)
# haversine loss
def haversine_loss(y, y_hat):
    return tf.math.asin(K.sqrt((K.sin(0.5*(y[:,0]-y_hat[:,0])*np.pi))**2 + K.cos((y[:,0])*np.pi)*K.cos((y_hat[:,0])*np.pi)*(K.sin(0.5*(y[:,1]-y_hat[:,1])*np.pi)**2)))
    
model2.compile(optimizer=adam_optimizer_fn, loss='mean_squared_error', metrics=['mean_squared_error']) 
# summarize model
model2.summary()
print('Learning rate = ' + str(K.eval(model2.optimizer.lr)))
# Out:
# Model: "model2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 231504, 1)         0
# _________________________________________________________________
# conv0 (Conv1D)               (None, 463, 49)           24549
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 463, 49)           196
# _________________________________________________________________
# activation_1 (Activation)    (None, 463, 49)           0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 93, 49)            180124
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 93, 49)            196
# _________________________________________________________________
# activation_2 (Activation)    (None, 93, 49)            0
# _________________________________________________________________
# max_pool (MaxPooling1D)      (None, 46, 49)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2254)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1127)              2541385
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                22560
# _________________________________________________________________
# fc (Dense)                   (None, 2)                 42
# =================================================================
# Total params: 2,769,052
# Trainable params: 2,768,856
# Non-trainable params: 196
# _________________________________________________________________
# Learning rate = 1e-04

# %% [markdown]
# ## Train model

# %%
es = callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

history = model2.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 500, batch_size = 1, callbacks = [es])
# Out:
# Train on 4006 samples, validate on 1002 samples
# Epoch 1/500
# 4006/4006 [==============================] - 77s 19ms/step - loss: 0.3682 - mean_squared_error: 0.3682 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
# Epoch 2/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0403 - mean_squared_error: 0.0403 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 3/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 4/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 5/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 6/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 7/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 8/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 9/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 10/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 11/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 12/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 13/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 14/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 15/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 16/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 17/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 18/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 19/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 20/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 21/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 22/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 9.3378e-04 - mean_squared_error: 9.3378e-04 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 23/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 9.0050e-04 - mean_squared_error: 9.0050e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 24/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 9.5741e-04 - mean_squared_error: 9.5741e-04 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 25/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 8.6772e-04 - mean_squared_error: 8.6772e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 26/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 7.7951e-04 - mean_squared_error: 7.7951e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 27/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.6547e-04 - mean_squared_error: 7.6547e-04 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 28/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 7.2810e-04 - mean_squared_error: 7.2810e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 29/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.9235e-04 - mean_squared_error: 6.9235e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 30/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 6.3870e-04 - mean_squared_error: 6.3870e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 31/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.7572e-04 - mean_squared_error: 5.7572e-04 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 32/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.6641e-04 - mean_squared_error: 5.6641e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 33/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.7298e-04 - mean_squared_error: 5.7298e-04 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 34/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.9963e-04 - mean_squared_error: 5.9963e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 35/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.6854e-04 - mean_squared_error: 4.6855e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 36/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.8211e-04 - mean_squared_error: 4.8211e-04 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 37/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.6130e-04 - mean_squared_error: 4.6130e-04 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 38/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.0178e-04 - mean_squared_error: 5.0178e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 39/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 5.0618e-04 - mean_squared_error: 5.0618e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 40/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.5758e-04 - mean_squared_error: 4.5758e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 41/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.6027e-04 - mean_squared_error: 4.6027e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 42/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.1224e-04 - mean_squared_error: 4.1224e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 43/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 3.9488e-04 - mean_squared_error: 3.9488e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 44/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.8736e-04 - mean_squared_error: 3.8736e-04 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 45/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 4.0534e-04 - mean_squared_error: 4.0534e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 46/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.6507e-04 - mean_squared_error: 3.6507e-04 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 47/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.3931e-04 - mean_squared_error: 3.3932e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 48/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.5435e-04 - mean_squared_error: 3.5435e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 49/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 3.6426e-04 - mean_squared_error: 3.6425e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 50/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.1260e-04 - mean_squared_error: 3.1260e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 51/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.0057e-04 - mean_squared_error: 3.0057e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 52/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 2.6632e-04 - mean_squared_error: 2.6632e-04 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 53/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.8609e-04 - mean_squared_error: 2.8609e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 54/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 3.0478e-04 - mean_squared_error: 3.0478e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 55/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.6497e-04 - mean_squared_error: 2.6497e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 56/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.3919e-04 - mean_squared_error: 2.3919e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 57/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 2.4849e-04 - mean_squared_error: 2.4849e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 58/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.5283e-04 - mean_squared_error: 2.5283e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 59/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.4382e-04 - mean_squared_error: 2.4382e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 60/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.1045e-04 - mean_squared_error: 2.1045e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 61/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.2569e-04 - mean_squared_error: 2.2569e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 62/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.3515e-04 - mean_squared_error: 2.3515e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 63/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.1335e-04 - mean_squared_error: 2.1335e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 64/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.7298e-04 - mean_squared_error: 1.7298e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 65/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 2.0661e-04 - mean_squared_error: 2.0661e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 66/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.9108e-04 - mean_squared_error: 1.9108e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 67/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.9026e-04 - mean_squared_error: 1.9026e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 68/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.8581e-04 - mean_squared_error: 1.8581e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 69/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.8786e-04 - mean_squared_error: 1.8786e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 70/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.7229e-04 - mean_squared_error: 1.7229e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 71/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.7223e-04 - mean_squared_error: 1.7223e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 72/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.7808e-04 - mean_squared_error: 1.7808e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 73/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.4500e-04 - mean_squared_error: 1.4500e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 74/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.6174e-04 - mean_squared_error: 1.6174e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 75/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.6658e-04 - mean_squared_error: 1.6658e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 76/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.5736e-04 - mean_squared_error: 1.5736e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 77/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.4455e-04 - mean_squared_error: 1.4455e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 78/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.6139e-04 - mean_squared_error: 1.6139e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 79/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.5153e-04 - mean_squared_error: 1.5153e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 80/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.5443e-04 - mean_squared_error: 1.5443e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 81/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.5305e-04 - mean_squared_error: 1.5305e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 82/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.3483e-04 - mean_squared_error: 1.3483e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 83/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.4591e-04 - mean_squared_error: 1.4591e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 84/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2167e-04 - mean_squared_error: 1.2167e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 85/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.3083e-04 - mean_squared_error: 1.3083e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 86/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.3921e-04 - mean_squared_error: 1.3921e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 87/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.1572e-04 - mean_squared_error: 1.1572e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 88/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2018e-04 - mean_squared_error: 1.2018e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 89/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2630e-04 - mean_squared_error: 1.2630e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 90/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.3502e-04 - mean_squared_error: 1.3502e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 91/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.1813e-04 - mean_squared_error: 1.1813e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 92/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2560e-04 - mean_squared_error: 1.2560e-04 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 93/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.1022e-04 - mean_squared_error: 1.1022e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 94/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2480e-04 - mean_squared_error: 1.2480e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 95/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0895e-04 - mean_squared_error: 1.0895e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 96/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0994e-04 - mean_squared_error: 1.0994e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 97/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.1867e-04 - mean_squared_error: 1.1867e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 98/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0023e-04 - mean_squared_error: 1.0023e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 99/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0351e-04 - mean_squared_error: 1.0351e-04 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 100/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0852e-04 - mean_squared_error: 1.0852e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 101/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.2211e-04 - mean_squared_error: 1.2211e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 102/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0455e-04 - mean_squared_error: 1.0455e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 103/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0844e-04 - mean_squared_error: 1.0844e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 104/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.0038e-04 - mean_squared_error: 1.0038e-04 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 105/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.9484e-05 - mean_squared_error: 9.9484e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 106/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.6448e-05 - mean_squared_error: 8.6449e-05 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 107/500
# 4006/4006 [==============================] - 76s 19ms/step - loss: 1.1421e-04 - mean_squared_error: 1.1421e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 108/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.1157e-04 - mean_squared_error: 1.1157e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 109/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.1428e-05 - mean_squared_error: 8.1428e-05 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 110/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.7935e-05 - mean_squared_error: 9.7935e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 111/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.4753e-05 - mean_squared_error: 8.4753e-05 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 112/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.7465e-05 - mean_squared_error: 9.7465e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 113/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.6329e-05 - mean_squared_error: 8.6329e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 114/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.3588e-05 - mean_squared_error: 8.3587e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 115/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.1674e-05 - mean_squared_error: 8.1674e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 116/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.6672e-05 - mean_squared_error: 9.6672e-05 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 117/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 1.1944e-04 - mean_squared_error: 1.1944e-04 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 118/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.5233e-05 - mean_squared_error: 6.5233e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 119/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.6960e-05 - mean_squared_error: 7.6960e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 120/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.9035e-05 - mean_squared_error: 7.9035e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 121/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.5194e-05 - mean_squared_error: 8.5194e-05 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 122/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.2905e-05 - mean_squared_error: 9.2905e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 123/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.3067e-05 - mean_squared_error: 7.3067e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 124/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.8603e-05 - mean_squared_error: 7.8603e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 125/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.2545e-05 - mean_squared_error: 9.2545e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 126/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.3084e-05 - mean_squared_error: 7.3084e-05 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 127/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.8879e-05 - mean_squared_error: 7.8879e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 128/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 9.2052e-05 - mean_squared_error: 9.2052e-05 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 129/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.5423e-05 - mean_squared_error: 6.5423e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 130/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.3754e-05 - mean_squared_error: 7.3754e-05 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 131/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.3895e-05 - mean_squared_error: 8.3895e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 132/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.5337e-05 - mean_squared_error: 7.5337e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 133/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 5.7724e-05 - mean_squared_error: 5.7724e-05 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 134/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.9808e-05 - mean_squared_error: 6.9808e-05 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 135/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 8.7793e-05 - mean_squared_error: 8.7793e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 136/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.5772e-05 - mean_squared_error: 7.5772e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 137/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.0477e-05 - mean_squared_error: 6.0477e-05 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 138/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.1832e-05 - mean_squared_error: 7.1832e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 139/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.9318e-05 - mean_squared_error: 6.9318e-05 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 140/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.4205e-05 - mean_squared_error: 7.4205e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 141/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.6032e-05 - mean_squared_error: 7.6032e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 142/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.4348e-05 - mean_squared_error: 7.4348e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 143/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.4723e-05 - mean_squared_error: 6.4723e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 144/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.7090e-05 - mean_squared_error: 6.7090e-05 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 145/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.3182e-05 - mean_squared_error: 6.3182e-05 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 146/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 6.8105e-05 - mean_squared_error: 6.8105e-05 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 147/500
# 4006/4006 [==============================] - 75s 19ms/step - loss: 7.0489e-05 - mean_squared_error: 7.0488e-05 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 148/500
# 1244/4006 [========>.....................] - ETA: 48s - loss: 5.8193e-05 - mean_squared_error: 5.8192e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e52c9741e373> in <module>
#       1 es = callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#       2
# ----> 3 history = model2.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 500, batch_size = 1, callbacks = [es])
#       4
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# 1) create loss and accuracy plots
_, train_acc = model2.evaluate(X_train, Y_train, verbose=0)
_, test_acc = model2.evaluate(X_test, Y_test, verbose=0)
# 1.1) plot loss during training
pyplot.figure(1, (9,9))
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
print('train mse:', train_acc)
print('test mse:', test_acc)

# %%
# re-scale longitudes and latitudes
Y_pred = model2.predict(X_test, verbose=1)
Y_test[:,1] = Y_test[:,1]*180 
Y_test[:,0] = Y_test[:,0]*90
Y_pred[:,1] = Y_pred[:,1]*180
Y_pred[:,0] = Y_pred[:,0]*90
# Out:
# 1002/1002 [==============================] - 1s 1ms/step

# %%
Y_pred2 = model2.predict(X_train, verbose=1)
Y_train[:,1] = Y_train[:,1]*180 
Y_train[:,0] = Y_train[:,0]*90
Y_pred2[:,1] = Y_pred2[:,1]*180
Y_pred2[:,0] = Y_pred2[:,0]*90
# Out:
# 4006/4006 [==============================] - 5s 1ms/step

# %%
# display a sample of predictions and ground truths 
np.set_printoptions(suppress=True) # to suppress numbers being displayed in scientific notation
print('Sample ground truths: ')
print(Y_test)
print(' ')
print('Sample predictions: ')
print(Y_pred)
# Out:
# Sample ground truths:
# [[ 42.1       12.      ]
#  [ 13.1      -59.62    ]
#  [  9.06666    7.483333]
#  ...
#  [ 31.554606  74.357158]
#  [ -1.27      36.61    ]
#  [ 52.486243  -1.890401]]
#
# Sample predictions:
# [[ 37.14583     3.5697997]
#  [ 12.1153755 -14.9607935]
#  [  9.150286   -0.7446132]
#  ...
#  [ 26.600918   65.96935  ]
#  [  5.289696    9.763765 ]
#  [ 40.454674  -15.827148 ]]

# %%
# generate map with ground truth labels and predictions of train set
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# centroids = world.centroid
# centroid_list = pd.concat([world.name, centroids], axis=1)
# Plot the results
base = world.plot(column='name', cmap='Blues', figsize=(16,8))
base.plot(Y_pred2[:,1], Y_pred2[:,0], 'r+')
base.plot(Y_train[:,1], Y_train[:,0], 'gx')
# centroids.plot(ax = base, marker = 'o', color = 'red', markersize = 5)

# %%
# generate map with ground truth labels and predictions of test set
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# centroids = world.centroid
# centroid_list = pd.concat([world.name, centroids], axis=1)
# Plot the results
base = world.plot(column='name', cmap='Blues', figsize=(16,8))
base.plot(Y_test[:,1], Y_test[:,0], 'gx')
base.plot(Y_pred[:,1], Y_pred[:,0], 'r+')
# centroids.plot(ax = base, marker = 'o', color = 'red', markersize = 5)

# %%
# store model and other vital files. DON't ACCIDENTALLY RUN THIS CELL!
# model2.save_weights("model2.h5")
# save('Y_test.npy', Y_test)
# save('X_test.npy', X_test)
# save('Y_train.npy', Y_train)
# save('X_train.npy', X_train)

# %%
# load model and other vital files to run last few cells
model2.load_weights("model2.h5")
Y_test = np.load('Y_test.npy')
X_test = np.load('X_test.npy')
Y_train = np.load('Y_train.npy')
X_train = np.load('X_train.npy')
Y_pred = model2.predict(X_test, verbose=1)
Y_pred[:,1] = Y_pred[:,1]*180
Y_pred[:,0] = Y_pred[:,0]*90
Y_pred2 = model2.predict(X_train, verbose=1)
Y_pred2[:,1] = Y_pred2[:,1]*180
Y_pred2[:,0] = Y_pred2[:,0]*90
# Out:
# 1002/1002 [==============================] - 2s 2ms/step
# 4006/4006 [==============================] - 7s 2ms/step

# %%
# generate map with ground truth labels and predictions color coded by ground truth labels
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base1 = world.plot(figsize=(15,6), color='white', edgecolor='black')
# plot predictions
for i in range(len(Y_pred[:,1])):
    if (math.isclose(Y_train[i,0], 26.0, abs_tol=0.05) and math.isclose(Y_train[i,1], 64.0, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color='k')
    elif (math.isclose(Y_train[i,0], 35.483, abs_tol=0.05) and math.isclose(Y_train[i,1], -97.53333, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*9/26))
    elif (math.isclose(Y_train[i,0], 7.4, abs_tol=0.05) and math.isclose(Y_train[i,1], 3.92, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*24/26))
    elif (math.isclose(Y_train[i,0], -1.27, abs_tol=0.05) and math.isclose(Y_train[i,1], 36.61, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*11/26))
    elif (math.isclose(Y_train[i,0], 35.68, abs_tol=0.05) and math.isclose(Y_train[i,1], 139.68, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*4/26))
    elif (math.isclose(Y_train[i,0], 22.0, abs_tol=0.05) and math.isclose(Y_train[i,1], 100.78, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*5/26))
    elif (math.isclose(Y_train[i,0], 40.767, abs_tol=0.05) and math.isclose(Y_train[i,1], -111.8904, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*6/26))
    elif (math.isclose(Y_train[i,0], 39.916666, abs_tol=0.05) and math.isclose(Y_train[i,1], 116.38333300000001, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*7/26))
    elif (math.isclose(Y_train[i,0], 23.02, abs_tol=0.05) and math.isclose(Y_train[i,1], 72.58, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*8/26))
    elif (math.isclose(Y_train[i,0], 13.09, abs_tol=0.05) and math.isclose(Y_train[i,1], 80.27, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*1/26))
    elif (math.isclose(Y_train[i,0], 13.454876, abs_tol=0.05) and math.isclose(Y_train[i,1], -16.579032, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*10/26))
    elif (Y_train[i,0] == 42.1 and Y_train[i,1] == 12.0): 
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*2/26))
    elif (math.isclose(Y_train[i,0], 31.554606, abs_tol=0.05) and math.isclose(Y_train[i,1], 74.357158, abs_tol=0.05)): 
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*3/26))
    elif (math.isclose(Y_train[i,0], 4.58333, abs_tol=0.05) and math.isclose(Y_train[i,1], -74.066666, abs_tol=0.05)): 
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*13/26))
    elif (math.isclose(Y_train[i,0], 60.17, abs_tol=0.05) and math.isclose(Y_train[i,1], 24.93, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*14/26))
    elif (math.isclose(Y_train[i,0], 23.7, abs_tol=0.05) and math.isclose(Y_train[i,1], 90.35, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*17/26))
    elif (math.isclose(Y_train[i,0], 8.48, abs_tol=0.05) and math.isclose(Y_train[i,1], -13.23, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*16/26))
    elif (math.isclose(Y_train[i,0], 40.38, abs_tol=0.05) and math.isclose(Y_train[i,1], -3.72, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*12/26))
    elif (math.isclose(Y_train[i,0], 9.06666, abs_tol=0.05) and math.isclose(Y_train[i,1], 7.483333, abs_tol=0.05)): 
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*18/26))
    elif (math.isclose(Y_train[i,0], 34.0544, abs_tol=0.05) and math.isclose(Y_train[i,1], -118.2439, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*19/26))
    elif (math.isclose(Y_train[i,0], 10.78, abs_tol=0.05) and math.isclose(Y_train[i,1], 106.68, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*20/26))
    elif (math.isclose(Y_train[i,0], 13.1, abs_tol=0.05) and math.isclose(Y_train[i,1], -59.62, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*21/26))
    elif (math.isclose(Y_train[i,0], -12.04, abs_tol=0.05) and math.isclose(Y_train[i,1], -77.03, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*22/26))
    elif (math.isclose(Y_train[i,0], 23.133329999999997, abs_tol=0.05) and math.isclose(Y_train[i,1], 113.266667, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*23/26))
    elif (Y_train[i,0] == 18.4 and Y_train[i,1] == -66.1):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*15/26))
    elif (math.isclose(Y_train[i,0], 17.37, abs_tol=0.05) and math.isclose(Y_train[i,1], 73.48, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*2/26))
    elif (math.isclose(Y_train[i,0], 52.486243, abs_tol=0.05) and math.isclose(Y_train[i,1], -1.8904009999999998, abs_tol=0.05)):
        base1.plot(Y_pred2[i,1], Y_pred2[i,0], marker='*', color=cm(1.*26/26))
# plot ground truths
base1.plot(Y_train[:,1], Y_train[:,0], 'kx')
base1.set_title('Coordinate predictions on train set')
# Out:
# Text(0.5, 1, 'Coordinate predictions on train set')

# %%
# generate map with ground truth labels and predictions color coded by ground truth labels
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base2 = world.plot(figsize=(15,6), color='white', edgecolor='black')
# plot predictions
for i in range(len(Y_pred[:,1])):
    if (math.isclose(Y_test[i,0], 26.0, abs_tol=0.05) and math.isclose(Y_test[i,1], 64.0, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color='k')
    elif (math.isclose(Y_test[i,0], 35.483, abs_tol=0.05) and math.isclose(Y_test[i,1], -97.53333, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*9/26))
    elif (math.isclose(Y_test[i,0], 7.4, abs_tol=0.05) and math.isclose(Y_test[i,1], 3.92, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*24/26))
    elif (math.isclose(Y_test[i,0], -1.27, abs_tol=0.05) and math.isclose(Y_test[i,1], 36.61, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*11/26))
    elif (math.isclose(Y_test[i,0], 35.68, abs_tol=0.05) and math.isclose(Y_test[i,1], 139.68, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*4/26))
    elif (math.isclose(Y_test[i,0], 22.0, abs_tol=0.05) and math.isclose(Y_test[i,1], 100.78, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*5/26))
    elif (math.isclose(Y_test[i,0], 40.767, abs_tol=0.05) and math.isclose(Y_test[i,1], -111.8904, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*6/26))
    elif (math.isclose(Y_test[i,0], 39.916666, abs_tol=0.05) and math.isclose(Y_test[i,1], 116.38333300000001, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*7/26))
    elif (math.isclose(Y_test[i,0], 23.02, abs_tol=0.05) and math.isclose(Y_test[i,1], 72.58, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*8/26))
    elif (math.isclose(Y_test[i,0], 13.09, abs_tol=0.05) and math.isclose(Y_test[i,1], 80.27, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*1/26))
    elif (math.isclose(Y_test[i,0], 13.454876, abs_tol=0.05) and math.isclose(Y_test[i,1], -16.579032, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*10/26))
    elif (Y_test[i,0] == 42.1 and Y_test[i,1] == 12.0): 
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*2/26))
    elif (math.isclose(Y_test[i,0], 31.554606, abs_tol=0.05) and math.isclose(Y_test[i,1], 74.357158, abs_tol=0.05)): 
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*3/26))
    elif (math.isclose(Y_test[i,0], 4.58333, abs_tol=0.05) and math.isclose(Y_test[i,1], -74.066666, abs_tol=0.05)): 
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*13/26))
    elif (math.isclose(Y_test[i,0], 60.17, abs_tol=0.05) and math.isclose(Y_test[i,1], 24.93, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*14/26))
    elif (math.isclose(Y_test[i,0], 23.7, abs_tol=0.05) and math.isclose(Y_test[i,1], 90.35, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*17/26))
    elif (math.isclose(Y_test[i,0], 8.48, abs_tol=0.05) and math.isclose(Y_test[i,1], -13.23, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*16/26))
    elif (math.isclose(Y_test[i,0], 40.38, abs_tol=0.05) and math.isclose(Y_test[i,1], -3.72, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*12/26))
    elif (math.isclose(Y_test[i,0], 9.06666, abs_tol=0.05) and math.isclose(Y_test[i,1], 7.483333, abs_tol=0.05)): 
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*18/26))
    elif (math.isclose(Y_test[i,0], 34.0544, abs_tol=0.05) and math.isclose(Y_test[i,1], -118.2439, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*19/26))
    elif (math.isclose(Y_test[i,0], 10.78, abs_tol=0.05) and math.isclose(Y_test[i,1], 106.68, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*20/26))
    elif (math.isclose(Y_test[i,0], 13.1, abs_tol=0.05) and math.isclose(Y_test[i,1], -59.62, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*21/26))
    elif (math.isclose(Y_test[i,0], -12.04, abs_tol=0.05) and math.isclose(Y_test[i,1], -77.03, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*22/26))
    elif (math.isclose(Y_test[i,0], 23.133329999999997, abs_tol=0.05) and math.isclose(Y_test[i,1], 113.266667, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*23/26))
    elif (Y_test[i,0] == 18.4 and Y_test[i,1] == -66.1):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*15/26))
    elif (math.isclose(Y_test[i,0], 17.37, abs_tol=0.05) and math.isclose(Y_test[i,1], 73.48, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*2/26))
    elif (math.isclose(Y_test[i,0], 52.486243, abs_tol=0.05) and math.isclose(Y_test[i,1], -1.8904009999999998, abs_tol=0.05)):
        base2.plot(Y_pred[i,1], Y_pred[i,0], marker='*', color=cm(1.*26/26))
# plot ground truths
base2.plot(Y_test[:,1], Y_test[:,0], 'kx')
base2.set_title('Coordinate predictions on test set')
# Out:
# Text(0.5, 1, 'Coordinate predictions on test set')
